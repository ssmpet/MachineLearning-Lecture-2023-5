# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
filename = 'web/static/data/melon_song_v3.csv'
plist_filename1 = 'web/static/data/melon_playlist1.csv'
plist_filename2 = 'web/static/data/melon_playlist2_v2.csv'

# %%
df = pd.read_csv(filename)
plist1 = pd.read_csv(plist_filename1)
plist2 = pd.read_csv(plist_filename2)
df.shape, plist1.shape, plist2.shape
# Out:
# ((6243, 14), (3845, 5), (60264, 5))

# %%
df.songId = df.songId.astype(str)
plist1.plylstSeq = plist1.plylstSeq.astype(str)
plist2.songId = plist2.songId.astype(str)

df.genre.fillna('-', inplace=True)
df.fillna('', inplace=True)
df.lyric = df.lyric.str.replace('\r', '')
df.head(1)
# Out:
#    songId title artist     genre       album lyricist composer        date
# 0  418168    희재    성시경  발라드 국내영화  국화꽃 향기 OST      양재선      MGR  2003.02.01  \
#
#                                                  img  comment    like
# 0  https://cdnimg.melon.co.kr/cm/album/images/000...      332  138267  \
#
#                                                lyric            plylstSeq
# 0  햇살은 우릴 위해 내리고\n바람도 서롤 감싸게 했죠\n우리 웃음속에 계절은 오고\n...  445029956 411111859  \
#
#                    ly_summary
# 0  정말로 울면 내가 그댈 보내<br>준 것 같아서

# %%
# songId 별로 playlist 에 들어있는 개수
df['p_count'] = df.songId.apply(lambda x : len(plist1[plist1.songIds.str.contains(str(x))]))

# %%
# playlist에 가장 많이 들어가 있는 곡은? 
df.sort_values('p_count', ascending=False)[['songId', 'title', 'artist', 'album', 'date', 'p_count', 'img']].head(20)
# Out:
#         songId                     title        artist
# 2422      9390                   Doc와 춤을        DJ DOC  \
# 4702      3743                     그런 일은          박화요비
# 2596      7712  당신은 모르실거야 (CF - LIG 핑클편)  핑클 (Fin.K.L)
# 357   32491274                       아로하           조정석
# 2556      3680                     너를 위해           임재범
# 3804  35945927                     Ditto      NewJeans
# 3505  35454426                  Hype boy      NewJeans
# 3799  36356993                      I AM     IVE (아이브)
# 3308  30314784                       밤편지           아이유
# 2602      8302                   내게 오는 길           성시경
# 3508  35546497                After LIKE     IVE (아이브)
# 2623      8290                      처음처럼           성시경
# 354   30190630              첫눈처럼 너에게 가겠다    에일리(Ailee)
# 3817  35931532                     Candy     NCT DREAM
# 346   34657844                    사랑인가 봐          멜로망스
# 3806  35985167                       OMG      NewJeans
# 3507  35454425                 Attention      NewJeans
# 3495  34847378                 LOVE DIVE     IVE (아이브)
# 358    8203900                      너였다면           정승환
# 3565   3890826               All For You           서인국
#
#                                   album        date  p_count
# 2422                  Season‘s Greeting  2000.12.12      144  \
# 4702                             My All  2000.06.14      117
# 2596                Memories & Melodies  2001.04.13      113
# 357                슬기로운 의사생활 OST Part 3  2020.03.27      107
# 2556                 Story Of Two Years  2000.05.16      106
# 3804                     NewJeans 'OMG'  2022.12.19       93
# 3505        NewJeans 1st EP 'New Jeans'  2022.08.01       91
# 3799                           I've IVE  2023.04.10       88
# 3308                                밤편지  2017.03.24       88
# 2602                               처음처럼  2001.04.19       85
# 3508                         After LIKE  2022.08.22       85
# 2623                               처음처럼  2001.04.19       84
# 354                      도깨비 OST Part.9  2017.01.07       84
# 3817  Candy - Winter Special Mini Album  2022.12.16       83
# 346            사랑인가 봐 (사내맞선 OST 스페셜 트랙)  2022.02.18       81
# 3806                     NewJeans 'OMG'  2023.01.02       80
# 3507        NewJeans 1st EP 'New Jeans'  2022.08.01       79
# 3495                          LOVE DIVE  2022.04.05       79
# 358                    또 오해영 OST Part.5  2016.05.31       76
# 3565        응답하라 1997 Love Story Part 1  2012.08.28       76
#
#                                                     img
# 2422  https://cdnimg.melon.co.kr/cm/album/images/000...
# 4702  https://cdnimg.melon.co.kr/cm/album/images/000...
# 2596  https://cdnimg.melon.co.kr/cm/album/images/000...
# 357   https://cdnimg.melon.co.kr/cm2/album/images/10...
# 2556  https://cdnimg.melon.co.kr/cm/album/images/000...
# 3804  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 3505  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 3799  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 3308  https://cdnimg.melon.co.kr/cm/album/images/100...
# 2602  https://cdnimg.melon.co.kr/cm/album/images/000...
# 3508  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 2623  https://cdnimg.melon.co.kr/cm/album/images/000...
# 354   https://cdnimg.melon.co.kr/cm/album/images/100...
# 3817  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 346   https://cdnimg.melon.co.kr/cm2/album/images/10...
# 3806  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 3507  https://cdnimg.melon.co.kr/cm2/album/images/11...
# 3495  https://cdnimg.melon.co.kr/cm2/album/images/10...
# 358   https://cdnimg.melon.co.kr/cm/album/images/026...
# 3565  https://cdnimg.melon.co.kr/cm/album/images/021...

# %%
# 저장하기
# df.to_csv('web/static/data/best_song.csv', index=False)

# %%
# 불러다 쓰기
filename = 'data/best_song.csv'

df_song = pd.read_csv(filename)
df_song.songId = df_song.songId.astype(str)

df_song = df_song.sort_values('p_count', ascending=False)[['songId', 'title', 'artist', 'album', 'date', 'img', 'p_count']].head(10)
