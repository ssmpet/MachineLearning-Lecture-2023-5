# %%
import numpy as np
import pandas as pd

# %%
filename = 'data/melon_song_v3.csv'
plist_filename1 = 'data/melon_playlist1.csv'
plist_filename2 = 'data/melon_playlist2_v2.csv'

# %%
df = pd.read_csv(filename)
plist1 = pd.read_csv(plist_filename1)
plist2 = pd.read_csv(plist_filename2)
df.shape, plist1.shape, plist2.shape
# Out:
# ((6247, 15), (3845, 5), (60271, 4))

# %%
df[df.songId == 3620661]
# Out:
#        songId    title artist genre          album lyricist composer
# 1715  3620661  어떤날 둘이는    홍수철   NaN  그시절 그노래 제 20집      장욱조      장욱조  \
#
#           date                                                img  comment
# 1715  19901201  https://cdnimg.melon.co.kr/cm/album/images/020...        0  \
#
#       like                                              lyric
# 1715    16  어떤날 둘이는 좋아한다고\n어떤날 둘이는 사랑한다고\n어떤날 둘이는 변치 말자고\n...  \
#
#                 plylstSeq                                              total
# 1715  436050976 460454147  어떤 날 두다 좋아하다 어떤 날 두다 사랑 하다 어떤 날 두다 변치 말 자고 어떤 ...

# %%
df.loc['songId' == 3620661, ('lyric')] = 'test'

# %%
df[df.date == 0 ]
# Out:
#        songId         title artist     genre                album lyricist
# 1336  1185251        맨발의 청춘    최희준  성인가요/트로트       최희준 스타앨범 힛트 21       유호  \
# 1346  1185247        진고개 신사    최희준  성인가요/트로트       최희준 스타앨범 힛트 21      심영식
# 1365  1185254          엄처시하    최희준  성인가요/트로트       최희준 스타앨범 힛트 21      김석야
# 1366  1185249            종점    최희준  성인가요/트로트       최희준 스타앨범 힛트 21       유호
# 1371  1185246           하숙생    최희준  성인가요/트로트       최희준 스타앨범 힛트 21      김석야
# 1382  1125030      마음이 고와야지     남진  성인가요/트로트             남진 베스트 2      정두수
# 1388  1185250        빛과 그림자    최희준  성인가요/트로트       최희준 스타앨범 힛트 21      길옥윤
# 1396  1124998            우수     남진  성인가요/트로트             남진 베스트 2      정두수
# 1404  1185257          팔도강산    최희준  성인가요/트로트       최희준 스타앨범 힛트 21      신봉승
# 1405  1125994        하와이 연정    패티김  성인가요/트로트            패티김 베스트 2      길옥윤
# 1406  1125963        9월의 노래    패티김  성인가요/트로트            패티김 베스트 2      이희우
# 1420  1124975       별아 내가슴에     남진  성인가요/트로트             남진 베스트 1      정두수
# 1431  1124692      강촌에 살고싶네    나훈아  성인가요/트로트            나훈아 베스트 2      김설강
# 1436  1124854         님 그리워    나훈아  성인가요/트로트             트롯트 세상 1      심형섭
# 1440  1124945     미워도 다시 한번     남진  성인가요/트로트             남진 베스트 1      김진경
# 1447  1124702    사랑은 눈물의 씨앗    나훈아  성인가요/트로트            나훈아 베스트 2      남국인
# 1449  1125993        서울의 찬가    패티김  성인가요/트로트            패티김 베스트 2      길옥윤
# 1467  1125953      사랑이란 두글자    패티김  성인가요/트로트            패티김 베스트 1      길옥윤
# 1469  1125841        서산 갯마을    조미미  성인가요/트로트             조미미의 애창곡      김운하
# 1478  1124701          가지마오    나훈아  성인가요/트로트            나훈아 베스트 2       고향
# 1485  2520607           라라라    윤형주    포크/블루스  윤형주 골든앨범 (김희갑 작편곡집)      윤형주
# 1487  1125814     먼데서 오신 손님    조미미       발라드      조미미 전곡 BEST HIT       이호
# 1549  439176495 460454142  밀감 향 ~~~~ 기 풍 ~ 겨 오다 가다 싶다 내 고 ~~~ 향 칠백 ~~~ 리 ...
# 1550  413868198 450604834  희망 새 아침 밝다 발걸음 가볍다 태양 거리 푸르른 하늘 쳐다보다 오늘 그대 와 둘...
# 1563            460454142  이슬 젖다 넓다 초원 샛별 바라보다 피다 이름 모르다 꽃송이 새 파란 잔디 위 아침...
# 1571  404064869 455380102  좋아하다 좋아하다 당신 좋아하다 저 하늘 태양 돌다 하다 당신 좋아하다 좋아하다 좋...
# 1587  460454143 100067661  서로 좋아하다 서로 사랑 하다 서로 좋아하다 서로 가 사랑 하다 어쩌다 좋아하다 사...
# 1589  439176495 460454143  어쩌다 생각 나다 냉정하다 사람 이지만 그렇게 사랑 하다 기억 잊다 없다 때로는 보...
# 1610  439176495 462131273  나 애인 있다 나 애인 있다 언제 까지 언제 까지 행복하다 ~ 거야 나 애인 있다 ...
# 1636  439176495 460454148  저 산마루 깊다 밤 산새 잠들다 우뚝 선 고목 달빛 아래 외롭다 옛 사람 간곳 없다...
# 1732  460454148 483794266  못 잊다 못 잊다 못 잊다 사람 라면 언제 까지 당 신 곁 나르다 버리다 살다 못 ...
# 1835  471207933 439176590  울다 울다 왜 울다 , 고까짓 사랑 때문 빗속 거닐다 추억 일랑 씻다 버리다 , 한...
# 1837  439176590 436050976  아무 찾다 않다 바람 불다 언덕 이름 모르다 잡초 야 한송이 꽃 라면 향기 라도 있...
# 1843  439176590 490703382  가을 남다 떠나다 사람 겨울 아직 멀리 있다 사랑 하다 수록 깊다 슬픔 눈물 향기롭...
# 1914  439176590 406132658  말 하고 싶다 그대 떠나가다 내 사랑 오직 당신 뿐 이라고 말 하고 싶다 그대 떠나...
# 1965  439176590 100134848  그토록 사랑 하다 그녀 가 오늘밤 내 곁 에서 떠나가다 소리 내지 않다 어깨 들썩이...
# 2292  425524406 439476159  내 일 이면 잊다 꼭 잊다 립스틱 짙다 바르다 사랑 이란 길다 않다 영원하다 않다 ...
# 5842  425524406 487112967  코스모스 피다 정 든 고향역 이쁜이 곱쁜 모두 나오다 반기다 달다 고향 열차 설레다...

# %%
df.date.fillna(0, inplace=True)
df.date = df.date.astype(int).astype(str)
df.songId = df.songId.astype(str)
df.fillna('', inplace=True)
df.lyric = df.lyric.str.replace('\r', '')
df.head()
# Out:
#      songId                      title   artist      genre
# 0    418168                         희재      성시경   발라드 국내영화  \
# 1  35609035                    인생은 뷰티풀      김호중   발라드 국내영화
# 2   1046278                      서쪽 하늘      이승철   발라드 국내영화
# 3  35609034                        슬픈등      김호중   발라드 국내영화
# 4  35728845  고백 (영화 '동감' X 츄 (이달의 소녀))  츄(Chuu)  록/메탈 국내영화
#
#                        album lyricist composer      date
# 0                 국화꽃 향기 OST      양재선      MGR  20030201  \
# 1              인생은 뷰티풀: 비타돌체      김호중      김호중  20220907
# 2                     청연 OST      이승철      윤명선  20051220
# 3              인생은 뷰티풀: 비타돌체      김호중      김호중  20220907
# 4  고백 (영화 '동감' X 츄 (이달의 소녀))      강현민      강현민  20221016
#
#                                                  img  comment    like
# 0  https://cdnimg.melon.co.kr/cm/album/images/000...      332  138267  \
# 1  https://cdnimg.melon.co.kr/cm2/album/images/11...      197   17322
# 2  https://cdnimg.melon.co.kr/cm/album/images/003...       84   48109
# 3  https://cdnimg.melon.co.kr/cm2/album/images/11...      145   15389
# 4  https://cdnimg.melon.co.kr/cm2/album/images/11...       80   16902
#
#                                                lyric            plylstSeq
# 0  햇살은 우릴 위해 내리고 \n바람도 서롤 감싸게 했죠 \n우리 웃음속에 계절은 오고...  445029956 411111859  \
# 1  하나만 알고 둘은\n잘 모르는 사람입니다\n하루는 비틀거리고\n하루는 뒤뚱거리고\n...  457536944 474137187
# 2  서쪽하늘로 노을은 지고  \n이젠 슬픔이 돼버린 그대를  \n다시 부를수 없을 것 ...  426571097 405285190
# 3  누군가를 다시 만난다면\n여전히 나는 너를\n누군가를 다시 사랑하면\n영원히 나는 ...  457536944 515278519
# 4  말해야 하는데 네 앞에 서면\n아무 말 못 하는 내가 미워져\n용기를 내야 해 후회...  484732185 513801514
#
#                                                total
# 0  햇살 우릴 위해 내리다 바람 서 롤 감싸다 하다 우리 웃음 속 계절 오다 또 가다 ...
# 1  하나 만 고 둘 자다 모르다 사람 이다 하루 비틀 거리 고 하루 뒤뚱거리 고 월요일...
# 2  서쪽하늘 노을 지고 젠 슬픔 돼다 버리다 그대 다시 부르다 없다 같다 또 한번 불다...
# 3  누군가 다시 만나다 여전하다 나 너 누군가 다시 사랑 하다 영원하다 나 너 다시 또...
# 4  말 하다 하다 네 앞 서면 아무 말 못 하다 내 가 미우다 용기 내야 해 후회 하다...

# %%
df.isna().sum()
# Out:
# songId         0
# title          0
# artist         0
# genre          2
# album          0
# lyricist     398
# composer     402
# date          45
# img            0
# comment        0
# like           0
# lyric          0
# plylstSeq    121
# dtype: int64

# %%
for val in df.genre.unique():
    print(val)

# %%
# 장르별 노래 총합
df.pivot_table('songId', 'genre', aggfunc='count').sort_values('songId', ascending=False).head(10)
# Out:
#              songId
# genre
# 발라드             957
# 성인가요/트로트        819
# 댄스              692
# 랩/힙합            473
# 국내뮤지컬           472
# 록/메탈            467
# R&B/Soul        458
# 발라드 국내드라마       350
# 포크/블루스          295
# 인디음악 포크/블루스     275

# %%
# 발매년도별 노래 총합
df['year'] = df.date.str[:4]

# %%
df.pivot_table('songId', 'year', aggfunc='count').sort_values('songId', ascending=False).head(10)
# Out:
#       songId
# year
# 2023     677
# 2022     648
# 2021     464
# 2020     394
# 2019     334
# 2017     240
# 2018     234
# 2016     228
# 2010     153
# 2015     150

# %%
df.columns
# Out:
# Index(['songId', 'title', 'artist', 'genre', 'album', 'lyricist', 'composer',
#        'date', 'img', 'comment', 'like', 'lyric', 'plylstSeq', 'year'],
#       dtype='object')

# %%
plist1.songIds

# %%
# songId 별로 playlist 에 들어있는 개수
df['p_count'] = df.songId.apply(lambda x : len(plist1[plist1.songIds.str.contains(str(x))]))

# %%
# playlist에 가장 많이 들어가 있는 곡은? 
df.sort_values('p_count', ascending=False)[['songId', 'title', 'artist', 'genre', 'comment', 'like', 'year', 'p_count']].head(20)
# Out:
#         songId                     title        artist      genre  comment  \
# 1100      9390                   Doc와 춤을        DJ DOC         댄스       44
# 1775      3743                     그런 일은          박화요비   R&B/Soul      195
# 1275      7712  당신은 모르실거야 (CF - LIG 핑클편)  핑클 (Fin.K.L)        발라드       18
# 358   32491274                       아로하           조정석  발라드 국내드라마     1362
# 1235      3680                     너를 위해           임재범        발라드       15
# 504   35945927                     Ditto      NewJeans         댄스     3121
# 2240  35454426                  Hype boy      NewJeans         댄스     2123
# 2020  30314784                       밤편지           아이유        발라드     2461
# 498   36356993                      I AM     IVE (아이브)         댄스     2604
# 1281      8302                   내게 오는 길           성시경        발라드      136
# 2243  35546497                After LIKE     IVE (아이브)         댄스     3557
# 355   30190630              첫눈처럼 너에게 가겠다    에일리(Ailee)  발라드 국내드라마     1104
# 1302      8290                      처음처럼           성시경        발라드       31
# 520   35931532                     Candy     NCT DREAM         댄스     7254
# 347   34657844                    사랑인가 봐          멜로망스  발라드 국내드라마      259
# 506   35985167                       OMG      NewJeans         댄스     1729
# 2228  34847378                 LOVE DIVE     IVE (아이브)         댄스     2737
# 2242  35454425                 Attention      NewJeans         댄스     2592
# 359    8203900                      너였다면           정승환  발라드 국내드라마      364
# 63     3890826               All For You           서인국        발라드      195
#
#         like  year  p_count
# 1100   14328  2000      144
# 1775   58243  2000      117
# 1275    4504  2001      113
# 358   245265  2020      107
# 1235   11306  2000      106
# 504   257135  2022       93
# 2240  263943  2022       91
# 2020  455469  2017       88
# 498   156948  2023       88
# 1281  108198  2001       85
# 2243  228833  2022       85
# 355   350646  2017       84
# 1302    8913  2001       84
# 520   150716  2022       83
# 347   185768  2022       81
# 506   181001  2023       80
# 2228  235956  2022       79
# 2242  223359  2022       79
# 359   235012  2016       76
# 63    177250  2012       76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6247 entries, 0 to 3844
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   songId     6247 non-null   int64
#  1   title      6247 non-null   object
#  2   artist     6247 non-null   object
#  3   genre      6245 non-null   object
#  4   album      6247 non-null   object
#  5   lyricist   5849 non-null   object
#  6   composer   5845 non-null   object
#  7   date       6247 non-null   object
#  8   img        6247 non-null   object
#  9   comment    6247 non-null   int64
#  10  like       6247 non-null   object
#  11  lyric      6242 non-null   object
#  12  plylstSeq  6126 non-null   object
#  13  year       6247 non-null   object
#  14  p_list     6247 non-null   int64
#  15  p_count    6247 non-null   int64
# dtypes: int64(4), object(12)
# memory usage: 829.7+ KB

# %%
import re

for i in df.like.values:
    if re.search('[^0-9]', str(i)):
        print(i)
# Out:
# 총건수
# 											0

# %%
df[df.like.str.contains('\t')][['songId', 'like']]

# %%
df.like = df.like.astype(int)

# %%
# 좋아요가 가장 많이 들어가 있는 곡은? 
# df.sort_values('like', ascending=False)[['songId', 'title', 'artist', 'genre', 'comment', 'like', 'year', 'p_count']].head(20)
df.sort_values('like')

# %%
df = pd.read_csv('data/melon_genre_ost_230527.csv')

# %%
df.head()
# Out:
#      songId                      title   artist      genre
# 0    418168                         희재      성시경   발라드 국내영화  \
# 1  35609035                    인생은 뷰티풀      김호중   발라드 국내영화
# 2   1046278                      서쪽 하늘      이승철   발라드 국내영화
# 3  35609034                        슬픈등      김호중   발라드 국내영화
# 4  35728845  고백 (영화 '동감' X 츄 (이달의 소녀))  츄(Chuu)  록/메탈 국내영화
#
#                        album lyricist composer      date
# 0                 국화꽃 향기 OST      양재선      MGR  20030201  \
# 1              인생은 뷰티풀: 비타돌체      김호중      김호중  20220907
# 2                     청연 OST      이승철      윤명선  20051220
# 3              인생은 뷰티풀: 비타돌체      김호중      김호중  20220907
# 4  고백 (영화 '동감' X 츄 (이달의 소녀))      강현민      강현민  20221016
#
#                                                  img  comment    like
# 0  https://cdnimg.melon.co.kr/cm/album/images/000...      332  138267  \
# 1  https://cdnimg.melon.co.kr/cm2/album/images/11...      197   17322
# 2  https://cdnimg.melon.co.kr/cm/album/images/003...       84   48109
# 3  https://cdnimg.melon.co.kr/cm2/album/images/11...      145   15389
# 4  https://cdnimg.melon.co.kr/cm2/album/images/11...       80   16902
#
#                                                lyric            plylstSeq
# 0  햇살은 우릴 위해 내리고 \r\n바람도 서롤 감싸게 했죠 \r\n우리 웃음속에 계절...  445029956 411111859
# 1  하나만 알고 둘은\r\n잘 모르는 사람입니다\r\n하루는 비틀거리고\r\n하루는 뒤...  457536944 474137187
# 2  서쪽하늘로 노을은 지고  \r\n이젠 슬픔이 돼버린 그대를  \r\n다시 부를수 없...  426571097 405285190
# 3  누군가를 다시 만난다면\r\n여전히 나는 너를\r\n누군가를 다시 사랑하면\r\n영...  457536944 515278519
# 4  말해야 하는데 네 앞에 서면\r\n아무 말 못 하는 내가 미워져\r\n용기를 내야 ...  484732185 513801514

# %%
df.lyric = df.lyric.str.replace('\r', '')

# %%
df.head()
# Out:
#      songId                      title   artist      genre
# 0    418168                         희재      성시경   발라드 국내영화  \
# 1  35609035                    인생은 뷰티풀      김호중   발라드 국내영화
# 2   1046278                      서쪽 하늘      이승철   발라드 국내영화
# 3  35609034                        슬픈등      김호중   발라드 국내영화
# 4  35728845  고백 (영화 '동감' X 츄 (이달의 소녀))  츄(Chuu)  록/메탈 국내영화
#
#                        album lyricist composer      date
# 0                 국화꽃 향기 OST      양재선      MGR  20030201  \
# 1              인생은 뷰티풀: 비타돌체      김호중      김호중  20220907
# 2                     청연 OST      이승철      윤명선  20051220
# 3              인생은 뷰티풀: 비타돌체      김호중      김호중  20220907
# 4  고백 (영화 '동감' X 츄 (이달의 소녀))      강현민      강현민  20221016
#
#                                                  img  comment    like
# 0  https://cdnimg.melon.co.kr/cm/album/images/000...      332  138267  \
# 1  https://cdnimg.melon.co.kr/cm2/album/images/11...      197   17322
# 2  https://cdnimg.melon.co.kr/cm/album/images/003...       84   48109
# 3  https://cdnimg.melon.co.kr/cm2/album/images/11...      145   15389
# 4  https://cdnimg.melon.co.kr/cm2/album/images/11...       80   16902
#
#                                                lyric            plylstSeq
# 0  햇살은 우릴 위해 내리고 \n바람도 서롤 감싸게 했죠 \n우리 웃음속에 계절은 오고...  445029956 411111859
# 1  하나만 알고 둘은\n잘 모르는 사람입니다\n하루는 비틀거리고\n하루는 뒤뚱거리고\n...  457536944 474137187
# 2  서쪽하늘로 노을은 지고  \n이젠 슬픔이 돼버린 그대를  \n다시 부를수 없을 것 ...  426571097 405285190
# 3  누군가를 다시 만난다면\n여전히 나는 너를\n누군가를 다시 사랑하면\n영원히 나는 ...  457536944 515278519
# 4  말해야 하는데 네 앞에 서면\n아무 말 못 하는 내가 미워져\n용기를 내야 해 후회...  484732185 513801514
